# %% [markdown]
# # Industry 4.0 의 중심, AI - ML&DL

# %% [markdown]
# <div align='right'><font size=2 color='gray'>Machine Learning & Deep Learning with TensorFlow @ <font color='blue'><a href='https://www.facebook.com/jskim.kr'>FB / jskim.kr</a></font>, 김진수</font></div>
# <hr>

# %% [markdown]
# ## Tensorflow Programming Model
# > https://developers.google.com/codelabs/tensorflow-1-helloworld
# > - Before start...
# > - ML이란?
# > - 첫 ML 모델 만들기
# > - 신경망 학습시키기
# > - 모델 사용
# > - Congratulation

# %%
from images import bigpycraft_dl as bpc
from IPython.display import Image

# %% [markdown]
# ### <font color='brown'>Introduction - Activity Recognintion</font>

# %%
Image(bpc.DL01_IMG_01)

# %% [markdown]
# ### <font color='brown'>Understanding ML(=Machine Learning)</font>

# %%
# Rule-based Programming
Image(bpc.DL01_IMG_02)

# %%
# ML-based Programming
Image(bpc.DL01_IMG_03)

# %%
# ML-Model Predictions
Image(bpc.DL01_IMG_04)

# %%
# ML-Context
Image(bpc.DL01_IMG_05)

# %% [markdown]
# ### <font color='brown'>ML Model</font>

# %% [markdown]
# <table class="vertical-rules">
#     <tr>
#         <td colspan="1" rowspan="1"><p>X</p>
#         </td><td colspan="1" rowspan="1"><p>-1</p>
#         </td><td colspan="1" rowspan="1"><p>0</p>
#         </td><td colspan="1" rowspan="1"><p>1</p>
#         </td><td colspan="1" rowspan="1"><p>2</p>
#         </td><td colspan="1" rowspan="1"><p>3</p>
#         </td><td colspan="1" rowspan="1"><p>4</p>
#         </td>
#     </tr>
#     <tr>
#         <td colspan="1" rowspan="1"><p>Y</p>
#         </td><td colspan="1" rowspan="1"><p>-2</p>
#         </td><td colspan="1" rowspan="1"><p>1</p>
#         </td><td colspan="1" rowspan="1"><p>4</p>
#         </td><td colspan="1" rowspan="1"><p>7</p>
#         </td><td colspan="1" rowspan="1"><p>10</p>
#         </td><td colspan="1" rowspan="1"><p>13</p>
#         </td>
#     </tr>
# </table>
#
# $$Y = 3X + 1$$

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.9.1'

# %% [markdown]
# ### 신경망 정의 및 컴파일

# %% [markdown]
# > - 가장 간단한 신경망을 만듭니다. 레이어가 하나이고, 레이어에 뉴런이 하나 있으며, 입력 도형은 값이 하나뿐입니다.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# > - 그런 다음 신경망을 컴파일하는 코드를 작성합니다. 이렇게 하려면 loss와 optimizer을 두 가지 함수로 지정해야 합니다.
# > - 먼저 손실에 mean_squared_error를 사용하고 옵티마이저에 스토크 경사하강법(sgd)을 사용하도록 지시하는 방법을 알아보겠습니다

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ### 데이터 제공

# %% [markdown]
# > - NumPy라는 Python 라이브러리는 이를 위한 다양한 배열 유형 데이터 구조를 제공합니다.
# > - np.array[]를 사용하여 NumPy의 배열로 값을 지정합니다.

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# ### 신경망 학습

# %% [markdown]
# > - X와 Y의 관계를 학습하는 신경망을 학습시키는 과정은 model.fit 호출에서 이루어집니다.
# > - 추측을 하기 전에 루프를 빠뜨리거나 어떤 손실이 좋은지 또는 손실이 좋은지 측정하거나, 최적화 도구를 사용하여 또 다시 추측하는 것입니다.
# > - 지정한 세대의 수만큼 계산됩니다. 해당 코드를 실행하면 에포크마다 손실이 출력됩니다.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 200ms/step - loss: 45.4696
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 35.7751
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 28.1479
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 22.1472
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 17.4261
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 13.7117
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.7893
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4902
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6812
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2580
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1383
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2573
# ...

# %% [markdown]
# ### 모델 사용

# %% [markdown]
# > - X와 Y의 관계를 학습하도록 학습된 모델이 있습니다.
# > - model.predict 메서드를 사용하여 이전에 알려지지 않은 X의 Y를 파악할 수 있습니다.
# > - 예를 들어 X가 10이라면 Y는 어떻게 될까요? 다음 코드를 실행하기 전에 추측해 보세요.

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 66ms/step
# [[31.001608]]

# %%
int(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 31

# %%
np.floor(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# array([[31.]], dtype=float32)

# %%
print(format(float(model.predict([10.0])), '.2f'))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 31.00

# %% [markdown]
# <hr>
# <marquee><font size=3 color='brown'>The BigpyCraft find the information to design valuable society with Technology & Craft.</font></marquee>
# <div align='right'><font size=2 color='gray'> &lt; The End &gt; </font></div>
