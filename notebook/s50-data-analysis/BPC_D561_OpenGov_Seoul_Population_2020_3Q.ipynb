# %% [markdown]
# # Industry 4.0 의 중심, BigData

# %% [markdown]
# <div align='right'><font size=2 color='gray'>Data Processing Based Python @ <font color='blue'><a href='https://www.facebook.com/jskim.kr'>FB / jskim.kr</a></font>, [김진수](bigpycraft@gmail.com)</font></div>
# <hr>

# %% [markdown]
# ## 서울시 구별 인구 현황

# %% [markdown]
# ### 서울시 통계DB
# - http://stat.seoul.go.kr/jsp3/index.jsp
# - 서울에서 인구수가 많으면 고령비율도 높을까?

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize'] = (10,6)

from IPython.display import Image

reference = lambda file, w=None, h=None : \
    Image(filename=file, width=w, height=h) 
    
population_img = 'images/Report_seoul_population_2019_2Q.png'
population_xls = './data/Report_seoul_population_2019_2Q.xls'
population_txt = './data/Report_seoul_population_2020_3Q.txt'
population_hml = './data/Report_seoul_population_2020_3Q.hml'

# %%
Image(population_img)

# %%
population_df = pd.read_table(population_txt, 
                           header=2
                    )
population_df.head()
# Out:
#          기간  자치구         세대          계         남자         여자        계.1  \
# 0  2020.3/4   합계  4,405,833  9,953,009  4,840,912  5,112,097  9,699,232
# 1  2020.3/4  종로구     74,861    159,842     77,391     82,451    149,952
# 2  2020.3/4   중구     63,594    135,321     66,193     69,128    125,800
# 3  2020.3/4  용산구    112,451    244,953    119,074    125,879    229,786
# 4  2020.3/4  성동구    136,096    302,695    147,582    155,113    295,591
#
#         남자.1       여자.1      계.2     남자.2     여자.2  세대당인구   65세이상고령자
# 0  4,719,170  4,980,062  253,777  121,742  132,035   2.20  1,552,356
# 1     73,024     76,928    9,890    4,367    5,523   2.00     28,396
# 2     61,526     64,274    9,521    4,667    4,854   1.98     24,265
# 3    110,604    119,182   15,167    8,470    6,697   2.04     39,995
# 4    144,444    151,147    7,104    3,138    3,966   2.17     45,372

# %%
population = population_df[['자치구', '세대', '계', '세대당인구', '65세이상고령자']]
population.head()
# Out:
#    자치구         세대          계  세대당인구   65세이상고령자
# 0   합계  4,405,833  9,953,009   2.20  1,552,356
# 1  종로구     74,861    159,842   2.00     28,396
# 2   중구     63,594    135,321   1.98     24,265
# 3  용산구    112,451    244,953   2.04     39,995
# 4  성동구    136,096    302,695   2.17     45,372

# %%
for idx in population.index:
    # print(population['계'][idx].replace(',', ''))
    tmp = population['세대'][idx]
    tmp = tmp.replace(',', '')
    population['세대'][idx] = tmp
# Out:
# <ipython-input-6-6dff95b35868>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['세대'][idx] = tmp
# C:\Python\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for idx in population.index:
    # print(population['계'][idx].replace(',', ''))
    tmp = population['65세이상고령자'][idx]
    tmp = tmp.replace(',', '')
    population['65세이상고령자'][idx] = tmp
# Out:
# <ipython-input-7-e442075c4ca5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['65세이상고령자'][idx] = tmp

# %%
for idx in population.index:
    # print(population['계'][idx].replace(',', ''))
    tmp = population['계'][idx]
    print(tmp, end='  \t-->  ')
    tmp = tmp.replace(',', '')
    # tmp = tmp.strip()
    print(tmp, type(tmp))
    population['계'][idx] = tmp
# Out:
# 9,953,009  	-->  9953009 <class 'str'>
# 159,842  	-->  159842 <class 'str'>
# 135,321  	-->  135321 <class 'str'>
# 244,953  	-->  244953 <class 'str'>
# 302,695  	-->  302695 <class 'str'>
# 361,923  	-->  361923 <class 'str'>
# 358,679  	-->  358679 <class 'str'>
# 400,989  	-->  400989 <class 'str'>
# 449,871  	-->  449871 <class 'str'>
# 313,550  	-->  313550 <class 'str'>
# 329,300  	-->  329300 <class 'str'>
# 529,532  	-->  529532 <class 'str'>
# 485,842  	-->  485842 <class 'str'>
# 323,860  	-->  323860 <class 'str'>
# 383,494  	-->  383494 <class 'str'>
# 460,048  	-->  460048 <class 'str'>
# 589,536  	-->  589536 <class 'str'>
# 435,751  	-->  435751 <class 'str'>
# 249,641  	-->  249641 <class 'str'>
# 405,982  	-->  405982 <class 'str'>
# 404,617  	-->  404617 <class 'str'>
# 514,555  	-->  514555 <class 'str'>
# 429,995  	-->  429995 <class 'str'>
# 544,085  	-->  544085 <class 'str'>
# 676,673  	-->  676673 <class 'str'>
# 462,275  	-->  462275 <class 'str'>
# <ipython-input-8-19d0fa580717>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['계'][idx] = tmp

# %%
population['세대'] = population['세대'].astype('int64')
# Out:
# <ipython-input-9-c7c1b7866665>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['세대'] = population['세대'].astype('int64')

# %%
population['65세이상고령자'] = population['65세이상고령자'].astype('int64')
# Out:
# <ipython-input-10-f31e8c56d060>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['65세이상고령자'] = population['65세이상고령자'].astype('int64')

# %%
population['계'] = population['계'].astype('int64')
# Out:
# <ipython-input-14-892d7f9a1c06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['계'] = population['계'].astype('int64')

# %%
population['세대'][1]
# Out:
# 74861

# %%
population['계'][1]
# Out:
# 159842

# %%
population['65세이상고령자'][1]
# Out:
# 28396

# %%
# population = pd.read_excel(population_xls, 
#                            header=2,
#                            # parse_cols="B, C, D, M, N"
#                            usecols="B, C, D, M, N"
#                     )
# population.head()

# %%
population.tail()
# Out:
#     자치구      세대       계  세대당인구  65세이상고령자
# 21  관악구  275248  514555   1.81     78206
# 22  서초구  173483  429995   2.46     59495
# 23  강남구  234021  544085   2.30     73942
# 24  송파구  281417  676673   2.38     92149
# 25  강동구  194602  462275   2.35     68798

# %% [markdown]
# #### <font color='blue'> # unique 체크후, 합계오 nan 부분을 drop </font>

# %%
population['자치구'].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype=object)

# %%
population = population.drop([0])
population
# Out:
#      자치구      세대       계  세대당인구  65세이상고령자
# 1    종로구   74861  159842   2.00     28396
# 2     중구   63594  135321   1.98     24265
# 3    용산구  112451  244953   2.04     39995
# 4    성동구  136096  302695   2.17     45372
# 5    광진구  166857  361923   2.09     50047
# 6   동대문구  167232  358679   2.06     61408
# 7    중랑구  185109  400989   2.14     68658
# 8    성북구  195379  449871   2.25     73370
# 9    강북구  145790  313550   2.13     62951
# 10   도봉구  139029  329300   2.35     61388
# 11   노원구  218002  529532   2.41     84612
# 12   은평구  213039  485842   2.26     84353
# 13  서대문구  144494  323860   2.17     53869
# 14   마포구  178495  383494   2.09     54053
# 15   양천구  180309  460048   2.53     64804
# 16   강서구  266366  589536   2.19     88052
# 17   구로구  179792  435751   2.26     69312
# 18   금천구  113887  249641   2.04     39361
# 19  영등포구  182087  405982   2.06     60826
# 20   동작구  184193  404617   2.14     64674
# 21   관악구  275248  514555   1.81     78206
# 22   서초구  173483  429995   2.46     59495
# 23   강남구  234021  544085   2.30     73942
# 24   송파구  281417  676673   2.38     92149
# 25   강동구  194602  462275   2.35     68798

# %%
population['자치구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
population.rename(columns = {'계':'인구수'}, inplace=True)
population.rename(columns = {'자치구':'구'}, inplace=True)
population.head()
# Out:
#      구      세대     인구수  세대당인구  65세이상고령자
# 1  종로구   74861  159842   2.00     28396
# 2   중구   63594  135321   1.98     24265
# 3  용산구  112451  244953   2.04     39995
# 4  성동구  136096  302695   2.17     45372
# 5  광진구  166857  361923   2.09     50047

# %%
sns.regplot(x="인구수", y="세대", data=population);

# %%
sns.regplot(x="인구수", y="65세이상고령자", data=population);

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\python\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in c:\python\anaconda3\lib\site-packages (from folium) (1.18.5)
# Requirement already satisfied: requests in c:\python\anaconda3\lib\site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\python\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\python\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\python\anaconda3\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\python\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %% [markdown]
# ### <font color='blue'> 참조.  https://github.com/southkorea/southkorea-maps/tree/master/kostat/2013/json </font>

# %%
import json
import folium
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
geo_path = 'data/skorea_municipalities_geo_simple.json'

geo_str = json.load(open(geo_path, encoding='utf-8'))
# geo_str

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['인구수']})
guDat.head()
# Out:
#     gu  counts
# 1  종로구  159842
# 2   중구  135321
# 3  용산구  244953
# 4  성동구  302695
# 5  광진구  361923

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='YlGnBu', #PuRd, YlGnBu
              key_on='feature.id')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['65세이상고령자']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['세대당인구']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
population['고령비율'] = population['65세이상고령자'] / population['인구수'] * 100
population.head()
# Out:
#      구      세대     인구수  세대당인구  65세이상고령자       고령비율
# 1  종로구   74861  159842   2.00     28396  17.765043
# 2   중구   63594  135321   1.98     24265  17.931437
# 3  용산구  112451  244953   2.04     39995  16.327622
# 4  성동구  136096  302695   2.17     45372  14.989346
# 5  광진구  166857  361923   2.09     50047  13.828079

# %%
guDat = pd.DataFrame({'gu':population['구'], 'counts':population['고령비율']})

map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

map.choropleth(geo_data=geo_str,
              data=guDat,
              columns=['gu', 'counts'],
              fill_color='PuRd', #PuRd, YlGnBu
              key_on='feature.id')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
population.sort_values(by='65세이상고령자', ascending=False).head(5)
# Out:
#       구      세대     인구수  세대당인구  65세이상고령자       고령비율
# 24  송파구  281417  676673   2.38     92149  13.617951
# 16  강서구  266366  589536   2.19     88052  14.935814
# 11  노원구  218002  529532   2.41     84612  15.978638
# 12  은평구  213039  485842   2.26     84353  17.362229
# 21  관악구  275248  514555   1.81     78206  15.198764

# %%
population.sort_values(by='인구수', ascending=False).head(5)
# Out:
#       구      세대     인구수  세대당인구  65세이상고령자       고령비율
# 24  송파구  281417  676673   2.38     92149  13.617951
# 16  강서구  266366  589536   2.19     88052  14.935814
# 23  강남구  234021  544085   2.30     73942  13.590156
# 11  노원구  218002  529532   2.41     84612  15.978638
# 21  관악구  275248  514555   1.81     78206  15.198764

# %%
population.sort_values(by='세대당인구', ascending=False).head(5)
# Out:
#       구      세대     인구수  세대당인구  65세이상고령자       고령비율
# 15  양천구  180309  460048   2.53     64804  14.086356
# 22  서초구  173483  429995   2.46     59495  13.836207
# 11  노원구  218002  529532   2.41     84612  15.978638
# 24  송파구  281417  676673   2.38     92149  13.617951
# 25  강동구  194602  462275   2.35     68798  14.882483

# %%
population.sort_values(by='고령비율', ascending=False).head(5)
# Out:
#       구      세대     인구수  세대당인구  65세이상고령자       고령비율
# 9   강북구  145790  313550   2.13     62951  20.076862
# 10  도봉구  139029  329300   2.35     61388  18.641968
# 2    중구   63594  135321   1.98     24265  17.931437
# 1   종로구   74861  159842   2.00     28396  17.765043
# 12  은평구  213039  485842   2.26     84353  17.362229

# %%
plt.rcParams["figure.figsize"] = [12,6]
df_population = pd.Series(population['인구수'].values, index=population['구'].values)
df_population.plot(kind='bar')

# %%
plt.rcParams["figure.figsize"] = [12,10]
df_population = pd.Series(population['세대당인구'].values, index=population['구'].values)
df_population.plot(kind='barh', color='orange')

# %%
plt.rcParams["figure.figsize"] = [12,12]
df_population = pd.Series(population['고령비율'].values, index=population['구'].values)
df_population.plot(kind='pie', autopct='%.2f', fontsize=15)

# %%
population.to_csv('data/seoul_population.csv', sep=',', index=False, encoding='euc-kr')

# %%
# %ls data

# %% [markdown]
# <hr>
# <marquee><font size=3 color='brown'>The BigpyCraft find the information to design valuable society with Technology & Craft.</font></marquee>
# <div align='right'><font size=2 color='gray'> &lt; The End &gt; </font></div>
