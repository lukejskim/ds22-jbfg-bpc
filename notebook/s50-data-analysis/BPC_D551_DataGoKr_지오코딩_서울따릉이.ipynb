# %% [markdown]
# <center>
# <b><font size=6>Industry 4.0 의 중심, BigData</font></b>
# </center>

# %% [markdown]
# <div align='right'><font size=2 color='gray'>Data Processing Based Python @ <font color='blue'><a href='https://www.facebook.com/jskim.kr'>FB / jskim.kr</a></font>, 김진수</font></div>
# <hr>

# %% [markdown]
# # 공공데이터 활용

# %% [markdown]
# ## 지오코딩(Geocoding)
# >
# > - 고유명칭(주소나 산,호수의 이름등)을 가지고 위도와 경도의 좌표값를 얻는 것
# > - 고유명칭이나 개별이름등을 가지고 검색하는것과는 달리 반대로 위도와 경도값으로부터 고유명칭을 얻는것은
# <br/> 리버스 지오코딩(reverse Geocoding)이된다.
# > - 도로명 주소와 같은 일반적인 주소는 OSM에 적용해서 데이터를 얻기 상당히 까다롭다.
# > - 반면에 (x, y) 좌표로 위치를 표현하게 되면 OSM이나 구글맵과 같은 기존의 맵 서비스들에서 더욱 정확한 위치를 찾을 수 있다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %% [markdown]
# ### geopy롤 지오코딩
# > - user_agent를 'South Korea'로 저장해줌으로써 한글 주소를 지오코딩할 수 있게 된다.
# > - geocoding이라는 함수는 address에 해당하는 좌표를 tuple 형태로 반환한다.

# %% [markdown]
# ### 지오코딩 목차
# >
# > - https://anweh.tistory.com/17 : 서울 따릉이 대여소 좌표 변환 및 지도 시각화
# > - https://blog.daum.net/geoscience/1659 : GeoPandas 설치
# > -
# > -
# > -
# > - https://anweh.tistory.com/42

# %% [markdown]
# ### GeoPandas 설치
# > https://blog.daum.net/geoscience/1659 : GeoPandas 설치
# > - pip install wheel
# > - pip install pipwin
#
# pipwin install numpy
# pipwin install pandas
# pipwin install shapely
# pipwin install gdal
# pipwin install fiona
# pipwin install pyproj
# pipwin install six
# pipwin install rtree
# pipwin install geopandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %% [markdown]
# ### 서울 따릉이 대여소 좌표 변환 및 지도 시각화
# >
# > - 데이터셋 : https://data.seoul.go.kr/dataList/OA-13252/F/1/datasetView.do

# %%
from pyproj import Transformer
import pyproj
import numpy as np
import pandas  as pd
from shapely.geometry import Point as point
# import geopandas as gpd
import folium

# %%
# %pip install fiona
# Out:
# Collecting fiona
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: cligj>=0.4 in c:\python\anaconda3\lib\site-packages (from fiona) (0.7.2)
# Requirement already satisfied: click-plugins in c:\python\anaconda3\lib\site-packages (from fiona) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\python\anaconda3\lib\site-packages (from fiona) (1.16.0)
# Requirement already satisfied: munch in c:\python\anaconda3\lib\site-packages (from fiona) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\python\anaconda3\lib\site-packages (from cligj>=0.4->fiona) (8.0.3)
# Requirement already satisfied: colorama in c:\python\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona) (0.4.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: fiona
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_62d7cd6227c0496284b3d9644a03bb38\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_62d7cd6227c0496284b3d9644a03bb38\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-ypvdkldo'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-xqhqry2y\fiona_62d7cd6227c0496284b3d9644a03bb38\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_98b7cb1e16b04613a86ee7a8de29f5bf\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_98b7cb1e16b04613a86ee7a8de29f5bf\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-r6wwnyi8'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-xqhqry2y\fiona_98b7cb1e16b04613a86ee7a8de29f5bf\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install
'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_9708b89f3e6c408585cfac85c60fba68\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-nv56n3s2'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-xqhqry2y\fiona_9708b89f3e6c408585cfac85c60fba68\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-wheel-xdgpne5g'
#        cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-xqhqry2y\fiona_bfb5cd4d423343e58051113c9df7c924\
#   Complete output (48 lines):
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#   creating build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   creating build\temp.win-amd64-3.9
#   creating build\temp.win-amd64-3.9\Release
#   creating build\temp.win-amd64-3.9\Release\fiona
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Python\anaconda3\include -IC:\Python\anaconda3\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#   _transform.cpp
#   fiona/_transform.cpp(606): fatal error C1083: 포함 파일을 열 수 없습니다. 'cpl_conv.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-record-juqj31nm\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python\anaconda3\Include\fiona'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-xqhqry2y\fiona_bfb5cd4d423343e58051113c9df7c924\
#     Complete output (18 lines):
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     creating build\temp.win-amd64-3.9
#     creating build\temp.win-amd64-3.9\Release
#     creating build\temp.win-amd64-3.9\Release\fiona
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Python\anaconda3\include -IC:\Python\anaconda3\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#     _transform.cpp
#     fiona/_transform.cpp(606): fatal error C1083: 포함 파일을 열 수 없습니다. 'cpl_conv.h': No such file or directory
#     error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-xqhqry2y\\fiona_bfb5cd4d423343e58051113c9df7c924\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-record-juqj31nm\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python\anaconda3\Include\fiona' Check the logs for full command output.

# %%
# %pip install geopandas
# Out:
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pandas>=0.25.0 in c:\python\anaconda3\lib\site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: pyproj>=2.2.0 in c:\python\anaconda3\lib\site-packages (from geopandas) (3.3.1)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.5.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.4.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.3.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.1.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Downloading geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Downloading geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Downloading Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: shapely in c:\python\anaconda3\lib\site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\python\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\python\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: certifi in c:\python\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\python\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.0->geopandas) (1.16.0)
# Collecting cligj>=0.4
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in c:\python\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (8.0.3)
# Requirement already satisfied: colorama in c:\python\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona->geopandas) (0.4.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.  Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: munch, cligj, click-plugins, fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c996facd5e2641ee9346abe6161022db\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c996facd5e2641ee9346abe6161022db\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-87g0g5r6'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-so1xvtc1\fiona_c996facd5e2641ee9346abe6161022db\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_e38ba4199e1d4447a493014dbfc49fc6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_e38ba4199e1d4447a493014dbfc49fc6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-kot9hf0x'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-so1xvtc1\fiona_e38ba4199e1d4447a493014dbfc49fc6\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_260cacb922ed44dbb60c42aa95280640\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_260cacb922ed44dbb60c42aa95280640\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-pip-egg-info-jpmmu2ty'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-so1xvtc1\fiona_260cacb922ed44dbb60c42aa95280640\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\
). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-wheel-p7n2sgqv'
#        cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-so1xvtc1\fiona_c56ad0650d3c41edb616756dff1578f8\
#   Complete output (48 lines):
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#   creating build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   creating build\temp.win-amd64-3.9
#   creating build\temp.win-amd64-3.9\Release
#   creating build\temp.win-amd64-3.9\Release\fiona
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Python\anaconda3\include -IC:\Python\anaconda3\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#   _transform.cpp
#   fiona/_transform.cpp(606): fatal error C1083: 포함 파일을 열 수 없습니다. 'cpl_conv.h': No such file or directory
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-record-ef07t6qg\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python\anaconda3\Include\fiona'
#          cwd: C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-install-so1xvtc1\fiona_c56ad0650d3c41edb616756dff1578f8\
#     Complete output (18 lines):
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Python\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     creating build\temp.win-amd64-3.9
#     creating build\temp.win-amd64-3.9\Release
#     creating build\temp.win-amd64-3.9\Release\fiona
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Python\anaconda3\include -IC:\Python\anaconda3\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\BuildTools\VC\Tools\MSVC\14.28.29910\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\cppwinrt /EHsc /Tpfiona/_transform.cpp /Fobuild\temp.win-amd64-3.9\Release\fiona/_transform.obj
#     _transform.cpp
#     fiona/_transform.cpp(606): fatal error C1083: 포함 파일을 열 수 없습니다. 'cpl_conv.h': No such file or directory
#     error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\BuildTools\\VC\\Tools\\MSVC\\14.28.29910\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Python\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"'; __file__='"'"'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-install-so1xvtc1\\fiona_c56ad0650d3c41edb616756dff1578f8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-record-ef07t6qg\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python\anaconda3\Include\fiona' Check the logs for full command output.

# %%
file_name = './data/seoul_public_bicycle_2021.12.xlsx'

# %%
# bike = pd.read_excel('C:/Users/user/Desktop/tta.xlsx') # 해당 엑셀 파일 불러오기
bike = pd.read_excel(file_name)
bike.head()
# Out:
#   대여소 검색_[(입력)란에 대여소 번호 입력해서 사용하세요!] Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                NaN        NaN        NaN        NaN
# 1                          대여소번호(입력)       대여소명        자치구         주소
# 2                               3762        NaN        NaN        NaN
# 3                                NaN        NaN        NaN        NaN
# 4                          대여소번호(입력)       대여소명        자치구         주소
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN        NaN        NaN
# 1       거치대수         방식       운영여부       설치시기
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4       거치대수         방식       운영여부       설치시기

# %%
bike_id = bike['대여소ID']
bike_x = bike['위도']
bike_y = bike['경도']

# %%
bike
# Out:
#    대여소 검색_[(입력)란에 대여소 번호 입력해서 사용하세요!] Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                 NaN        NaN        NaN        NaN
# 1                           대여소번호(입력)       대여소명        자치구         주소
# 2                                3762        NaN        NaN        NaN
# 3                                 NaN        NaN        NaN        NaN
# 4                           대여소번호(입력)       대여소명        자치구         주소
# 5                                1397        NaN        NaN        NaN
# 6                                 NaN        NaN        NaN        NaN
# 7                           대여소번호(입력)       대여소명        자치구         주소
# 8                                 234        NaN        NaN        NaN
# 9                                 NaN        NaN        NaN        NaN
# 10                          대여소번호(입력)       대여소명        자치구         주소
# 11                               4619        NaN        NaN        NaN
# 12                                NaN        NaN        NaN        NaN
# 13                          대여소번호(입력)       대여소명        자치구         주소
# 14                               2000        NaN        NaN        NaN
# 15                                NaN        NaN        NaN        NaN
# 16                          대여소번호(입력)       대여소명        자치구         주소
# 17                                255        NaN        NaN        NaN
# 18                                NaN        NaN        NaN        NaN
# 19                          대여소번호(입력)       대여소명        자치구         주소
# 20                               3304        NaN        NaN        NaN
# 21                                NaN        NaN        NaN        NaN
# 22                          대여소번호(입력)       대여소명        자치구         주소
# 23                                343        NaN        NaN        NaN
# 24                                NaN        NaN        NaN        NaN
# 25                          대여소번호(입력)       대여소명        자치구         주소
# 26                               2160        NaN        NaN        NaN
# 27                                NaN        NaN        NaN        NaN
# 28                          대여소번호(입력)       대여소명        자치구         주소
# 29                               1566        NaN        NaN        NaN
# 30                                NaN        NaN        NaN        NaN
# 31                          대여소번호(입력)       대여소명        자치구         주소
# 32                                216        NaN        NaN        NaN
# 33                                NaN        NaN        NaN        NaN
# 34                          대여소번호(입력)       대여소명        자치구         주소
# 35                               4496        NaN        NaN        NaN
# 36                                NaN        NaN        NaN        NaN
# 37                          대여소번호(입력)       대여소명        자치구         주소
# 38                               4497        NaN        NaN        NaN
# 39                                NaN        NaN        NaN        NaN
# 40                          대여소번호(입력)       대여소명        자치구         주소
# 41                               4498        NaN        NaN        NaN
# 42                                NaN        NaN        NaN        NaN
# 43                          대여소번호(입력)       대여소명        자치구         주소
# 44                               4499        NaN        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0         NaN        NaN        NaN        NaN
# 1        거치대수         방식       운영여부       설치시기
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# 4        거치대수         방식       운영여부       설치시기
# 5         NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN
# 7        거치대수         방식       운영여부       설치시기
# 8         NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN
# 10       거치대수         방식       운영여부       설치시기
# 11        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN
# 13       거치대수         방식       운영여부       설치시기
# 14        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN
# 16       거치대수         방식       운영여부       설치시기
# 17        NaN        NaN        NaN        NaN
# 18        NaN        NaN        NaN        NaN
# 19       거치대수         방식       운영여부       설치시기
# 20        NaN        NaN        NaN        NaN
# 21        NaN        NaN        NaN        NaN
# 22       거치대수         방식       운영여부       설치시기
# 23        NaN        NaN        NaN        NaN
# 24        NaN        NaN        NaN        NaN
# 25       거치대수         방식       운영여부       설치시기
# 26        NaN        NaN        NaN        NaN
# 27        NaN        NaN        NaN        NaN
# 28       거치대수         방식       운영여부       설치시기
# 29        NaN        NaN        NaN        NaN
# 30        NaN        NaN        NaN        NaN
# 31       거치대수         방식       운영여부       설치시기
# 32        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN
# 34       거치대수         방식       운영여부       설치시기
# 35        NaN        NaN        NaN        NaN
# 36        NaN        NaN        NaN        NaN
# 37       거치대수         방식       운영여부       설치시기
# 38        NaN        NaN        NaN        NaN
# 39        NaN        NaN        NaN        NaN
# 40       거치대수         방식       운영여부       설치시기
# 41        NaN        NaN        NaN        NaN
# 42        NaN        NaN        NaN        NaN
# 43       거치대수         방식       운영여부       설치시기
# 44        NaN        NaN        NaN        NaN

# %% [markdown]
# <hr>
# <marquee><font size=3 color='brown'>The BigpyCraft find the information to design valuable society with Technology & Craft.</font></marquee>
# <div align='right'><font size=2 color='gray'> &lt; The End &gt; </font></div>
