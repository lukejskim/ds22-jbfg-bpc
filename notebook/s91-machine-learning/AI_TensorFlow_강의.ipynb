# %% [markdown]
# # 모두를 위한 머신러닝/딥러닝 강의

# %% [markdown]
# <div align='right'>TensorFlow Based Python @ FB/jskim.kr, 김진수</div>

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## RL - Deep Reinforcement Learning
# - 구글이 공개한 머신러닝을 위한 오픈소스인 TensorFlow를 이용해서 이론을 구현
# - 수학이나 컴퓨터 공학적인 지식이 없이도 가능
# - 참고사이트 : https://hunkim.github.io/ml/
# - 동영상자료 : https://www.youtube.com/playlist?list=PLlMkM4tgfjnLSOjrEJN31gZATbcj_MpUm

# %%
# %reset

from IPython.display import Image
View = lambda file, w=None, h=None : \
    Image(filename=file, width=w, height=h) 

main1    = "images/Img_BestSandwitch_P1-1.png"
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?
# Nothing done.

# %% [markdown]
# ### <font color='brown'> TensorFlow : 머신러닝을 위한 오픈소스 패키지 </font>

# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen

# %%
# 모두를 위한 머신러닝/딥러닝 강의 
url  = 'https://www.youtube.com/playlist?list=PLlMkM4tgfjnLSOjrEJN31gZATbcj_MpUm'
url  = 'https://hunkim.github.io/ml/'
html = urlopen(url)
soup = BeautifulSoup(html, "lxml")

# %%
# View(main1, 800)|

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko-kr">
# <head>
# <meta charset="utf-8"/>
# <title>모두를 위한 머신러닝/딥러닝 강의</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="stylesheets/normalize.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700" rel="stylesheet" type="text/css"/>
# <link href="stylesheets/stylesheet.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="stylesheets/github-light.css" media="screen" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <section class="page-header">
# <h1 class="project-name">모두를 위한 머신러닝/딥러닝 강의</h1>
# <h2 class="project-tagline"></h2>
# </section>
# <section class="main-content">
# <!--
#         <h3><img src="img/new.png" width="44">이벤트: 2017년 TensorFlow 와 함께 딥러닝에 빠져들자!</h3>
#
#         <p>2017년 1월 한달동안 #모두를위한딥러닝 시즌 1 수업을 들으시는 100분에게 선물을 드립니다!</p>
#         <ul>
# ...

# %%
html_title = soup.title
html_title
# Out:
# <title>모두를 위한 머신러닝/딥러닝 강의</title>

# %%
tmp = soup.find('section', 'main-content')

# %%
tmp2 = tmp.findChild('ul')
len(tmp2)
# Out:
# 27

# %%
type(tmp2)
# Out:
# bs4.element.Tag

# %%
tmp2
# Out:
# <ul>
# <li>Lecture 1: 수업의 개요 <a href="https://youtu.be/dZ4vw6v3LcA">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl01.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <li>Lecture 2: OpenAI GYM 게임해보기 <a href="https://youtu.be/xgoO54qN4lY">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl02.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <ul>
# <li>Lab 2: OpenAI GYM 게임해보기 실습 <a href="https://youtu.be/xvDAURQVDhk">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl-l02.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# </ul>
# <li>Lecture 3: Dummy Q-learning (table) <a href="https://youtu.be/Vd-gmo-qO5E">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl03.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <ul>
# <li>Lab 3: Dummy Q-learning (table) <a href="https://youtu.be/yOBKtGU6CG0">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl-l03.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# </ul>
# ...

# %%
tmp3 = tmp2.find_next_siblings()
len(tmp3)
# Out:
# 13

# %%
# body > section.main-content > ul:nth-child(11)

# %%
tmp = soup.find_all('ul')
tmp
# Out:
# [<ul>
#  <li>Lecture 1: 수업의 개요 <a href="https://youtu.be/dZ4vw6v3LcA">비디오 <img src="video.png" width="20"/></a>
#  <a href="RL/rl01.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
#  </li>
#  <li>Lecture 2: OpenAI GYM 게임해보기 <a href="https://youtu.be/xgoO54qN4lY">비디오 <img src="video.png" width="20"/></a>
#  <a href="RL/rl02.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
#  </li>
#  <ul>
#  <li>Lab 2: OpenAI GYM 게임해보기 실습 <a href="https://youtu.be/xvDAURQVDhk">비디오 <img src="video.png" width="20"/></a>
#  <a href="RL/rl-l02.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
#  </li>
#  </ul>
#  <li>Lecture 3: Dummy Q-learning (table) <a href="https://youtu.be/Vd-gmo-qO5E">비디오 <img src="video.png" width="20"/></a>
#  <a href="RL/rl03.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
#  </li>
#  <ul>
#  <li>Lab 3: Dummy Q-learning (table) <a href="https://youtu.be/yOBKtGU6CG0">비디오 <img src="video.png" width="20"/></a>
#  <a href="RL/rl-l03.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
# ...

# %%
len(tmp)
# Out:
# 22

# %%
tmp[0]
# Out:
# <ul>
# <li>Lecture 1: 수업의 개요 <a href="https://youtu.be/dZ4vw6v3LcA">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl01.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <li>Lecture 2: OpenAI GYM 게임해보기 <a href="https://youtu.be/xgoO54qN4lY">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl02.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <ul>
# <li>Lab 2: OpenAI GYM 게임해보기 실습 <a href="https://youtu.be/xvDAURQVDhk">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl-l02.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# </ul>
# <li>Lecture 3: Dummy Q-learning (table) <a href="https://youtu.be/Vd-gmo-qO5E">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl03.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# <ul>
# <li>Lab 3: Dummy Q-learning (table) <a href="https://youtu.be/yOBKtGU6CG0">비디오 <img src="video.png" width="20"/></a>
# <a href="RL/rl-l03.pdf">실습슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# </ul>
# ...

# %%
tmp[21]
# Out:
# <ul>
# <li><a href="https://www.tensorflow.org">https://www.tensorflow.org</a></li>
# <li><a href="https://github.com/nlintz/TensorFlow-Tutorials">TensorFlow Tutorials (Simple Examples)</a></li>
# <li><a href="https://github.com/pkmital/tensorflow_tutorials">Another TensorFlow Tutorials</a></li>
# <li><a href="https://github.com/aymericdamien/TensorFlow-Examples">TensorFlow Examples</a></li>
# <li><a href="https://www.udacity.com/course/viewer#!/c-ud730/l-6370362152/m-6379811817">Deep
#     learning @Udacity</a></li>
# </ul>

# %%
# tmp2 = tmp[0]
type(tmp[0])
# Out:
# bs4.element.Tag

# %%
tags = soup.find_all('li')
len(tags)
# Out:
# 90

# %%
# for tag in tags:
#     print(tag.get_text())

# %%
for idx in range(21, len(tags)):
    text = tags[idx]
    print('{} : {}'.format(idx, text) )
# Out:
# 21 : <li> 수업에 사용하는 코드 <a href="https://github.com/hunkim/DeepLearningZeroToAll">https://github.com/hunkim/DeepLearningZeroToAll</a></li>
# 22 : <li>수업의 개요 <a href="https://www.youtube.com/watch?v=BS6O0zOGX4E">비디오 <img src="video.png" width="20"/></a>
# <a href="lec0.pdf">슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# 23 : <li>머신러닝의 개념과 용어 <a href="https://www.youtube.com/watch?v=qPMeuL2LIqY">비디오 <img src="video.png" width="20"/></a>
#   (TensorFlow의 기본 <a href="https://youtu.be/-57Ne86Ia8w">Lab 비디오 <img src="video.png" width="20"/></a>)
#  <a href="lec1.pdf">강의 슬라이드 <img src="pdf.png" width="20"/></a>
# <a href="https://docs.google.com/presentation/d/137IlT2N3AYcclqxNuc8j9RDrIeHiYkSZ5JPg_vg9Jqk/edit#slide=id.g1d115b0ec5_0_215">Lab 슬라이드 <img src="pdf.png" width="20"/></a>
# </li>
# 24 : <li>Linear Regression 의 개념 <a href="https://www.youtube.com/watch?v=Hax03rCn3UI">비디오 <img src="video.png" width="20"/></a>
# ...

# %% [markdown]
# <div align='right'> < To be continue > </div>
