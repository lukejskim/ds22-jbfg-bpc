# %% [markdown]
# <center>
# <b><font size=6>Industry 4.0 의 중심, AI - ML&DL</font></b>
# </center>

# %% [markdown]
# <div align='right'><font size=2 color='gray'>Machine Learning & Deep Learning with TensorFlow @ <font color='blue'><a href='https://www.facebook.com/jskim.kr'>FB / jskim.kr</a></font>, 김진수</font></div>
# <hr>

# %%
from images import bigpycraft_copy as bpc
# import images.bigpycraft_copy as bpc

# %%
# TensorFlow Mechanics
bpc.Figure(bpc.ML02_IMG_01)

# %% [markdown]
# # Python Review

# %% [markdown]
# ### <font color='blue'>Sub Title</font>

# %% [markdown]
# <hr>
# <marquee><font size=3 color='brown'>The BigpyCraft find the information to design valuable society with Technology & Craft.</font></marquee>
# <div align='right'><font size=2 color='gray'> &lt; The End &gt; </font></div>

# %%
# % reset

from IPython.display import Image
View = lambda file, w=None, h=None : \
    Image(filename=file, width=w, height=h) 
    
LOGO_TF_01   = "images/bg_logo_tensorflow_no_shadow_1.png"
ML01_IMG_01  = "images/lab01_Data_Flow_Graph.png"
ML01_IMG_02  = "images/lab01_install_TF_jupyter.png"
ML01_IMG_03  = "images/lab01_install_TF_pycharm.png"
ML01_IMG_04  = "images/lab01_TF_Mechanics1.png"
ML01_IMG_05  = "images/lab01_TF_Mechanics2.png"

ML02_IMG_01  = "images/lab02_TF_Mechanics1.png"
ML02_IMG_02  = "images/lab02_TF_Mechanics2.png"

ML03_IMG_01  = "images/lab03_tb_sect03.png"

# %% [markdown]
# ### Acknowledgement
# >
# - Andrew Ng's ML class
# <br> 강의 : https://class.coursera.org/ml-003/lecture
# <br> 노트 : http://www.holehouse.org/mlclass/
# - Convolutional Neural Networks for Visual Recognition.
# <br> http://cs231n.github.io/
# - Tensorflow
# <br> https://www.tensorflow.org
# <br> https://github.com/aymericdamien/TensorFlow-Examples

# %% [markdown]
# ### ACORN 텐서플로우 입문
# >
# - 소개 : http://www.kyobobook.co.kr/product/detailViewKor.laf?barcode=9788960779198
# - 자료 : https://github.com/czangyeob/AcornPub_Tensorflow

# %% [raw]
# <!--
# - 목차
# S01. 텐서플로: 기초
# S02. 텐서플로 기초 연산
# S03. 머신 러닝 시작
# S04. 인공 신경망 소개
# S05. 딥 러닝
# S06. GPU 프로그래밍과 텐서플로 서빙
# -->

# %% [markdown]
# ## 마크다운 사용법
# > https://gist.github.com/ihoneymon/652be052a0727ad59601

# %% [markdown]
# <hr>
#
# ### 마크다운이이란?

# %% [markdown]
# Markdown은 텍스트 기반의 마크업언어로 2004년 존그루버에 의해 만들어졌으며 쉽게 쓰고 읽을 수 있으며 HTML로 변환이 가능하다. 특수기호와 문자를 이용한 매우 간단한 구조의 문법을 사용하여 웹에서도 보다 빠르게 컨텐츠를 작성하고 보다 직관적으로 인식할 수 있다. 마크다운이 최근 각광받기 시작한 이유는 깃헙(https://github.com) 덕분이다. 깃헙의 저장소Repository에 관한 정보를 기록하는 README.md는 깃헙을 사용하는 사람이라면 누구나 가장 먼저 접하게 되는 마크다운 문서였다. 마크다운을 통해서 설치방법, 소스코드 설명, 이슈 등을 간단하게 기록하고 가독성을 높일 수 있다는 강점이 부각되면서 점점 여러 곳으로 퍼져가게 된다.

# %% [markdown]
# #### 장점
# 1. 간결하다.
# 2. 별도의 도구없이 작성가능하다.
# 3. 다양한 형태로 변환이 가능하다.
# 3. 텍스트(Text)로 저장되기 때문에 용량이 적어 보관이 용이하다.
# 4. 텍스트파일이기 때문에 버전관리시스템을 이용하여 변경이력을 관리할 수 있다.
# 5. 지원하는 프로그램과 플랫폼이 다양하다.

# %% [markdown]
# #### 단점
# 1. 표준이 없다.
# 2. 표준이 없기 때문에 도구에 따라서 변환방식이나 생성물이 다르다.
# 3. 모든 HTML 마크업을 대신하지 못한다.

# %% [markdown]
# ## 마크다운 사용법(문법)

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 1. 헤더Headers <font>

# %% [raw]
# # This is an H1
# =============

# %% [markdown]
# This is an H1
# =============

# %% [raw]
# # This is an H2
# -------------

# %% [markdown]
# This is an H2
# -------------

# %% [raw]
# # This is a H1
# ## This is a H2
# ### This is a H3
# #### This is a H4
# ##### This is a H5
# ###### This is a H6

# %% [markdown]
# # This is a H1
# ## This is a H2
# ### This is a H3
# #### This is a H4
# ##### This is a H5
# ###### This is a H6

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 2. BlockQuote <font>
# > 이메일에서 사용하는 > 블럭인용문자를 이용한다.

# %% [raw]
# > This is a blockqute.

# %% [markdown]
# > This is a blockqute.

# %% [raw]
# > This is a blockqute.
# >> This is a blockqute.
# >>> This is a blockqute.

# %% [markdown]
# > This is a blockqute.
# >> This is a blockqute.
# >>> This is a blockqute.

# %% [raw]
# ``` python
# import numpy as np
# print("Hello, Jupyter World!)
# ```

# %% [markdown]
# ``` python
# import numpy as np
# print("Hello, Jupyter World!)
# ```

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 3. 목록 <font>

# %% [markdown]
# ● 순서있는 목록(번호)
# > 순서있는 목록은 숫자와 점을 사용한다.

# %% [raw]
# 순서있는 목록은 숫자와 점을 사용한다.
#
# 1. 첫번째
# 2. 두번째
# 3. 세번째

# %% [markdown]
# 1. 첫번째
# 2. 두번째
# 3. 세번째

# %% [raw]
# 현재까지는 어떤 번호를 입력해도 순서는 내림차순으로 정의된다.
# 딱히 개선될 것 같지는 않다. 존 그루버가 신경안쓰고 있다고...
#
# 1. 첫번째
# 3. 세번째
# 2. 두번째

# %% [markdown]
# 1. 첫번째
# 3. 세번째
# 2. 두번째

# %% [markdown]
# ● 순서없는 목록(글머리 기호)

# %% [raw]
# * 빨강
#   * 녹색
#     * 파랑
#
# + 빨강
#   + 녹색
#     + 파랑
#
# - 빨강
#   - 녹색
#     - 파랑

# %% [markdown]
# * 빨강
#   * 녹색
#     * 파랑
#
# + 빨강
#   + 녹색
#     + 파랑
#
# - 빨강
#   - 녹색
#     - 파랑

# %% [raw]
# 혼합해서 사용하는 것도 가능하다(내가 선호하는 방식)
#
# * 1단계
#     - 2단계
#     	+ 3단계
#             = 4단계

# %% [markdown]
# * 1단계
#     - 2단계
#     	+ 3단계
#             = 4단계

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 4. 코드 <pre><code></code></pre> <font>

# %% [raw]
# 코드 <pre><code></code></pre>
#
# 4개의 공백 또는 하나의 탭으로 들여쓰기를 만나면 변환되기 시작하여 들여쓰지 않은 행을 만날때까지 변환이 계속된다.
#
# 한줄 띄어쓰면 인식이 제대로 안되는 문제가 발생하곤 합니다.

# %% [markdown]
# This is a normal paragraph:
#
#     This is a code block.
# end code block.

# %% [raw]
# ``` This is a normal paragraph: This is a code block. end code block. ```

# %% [markdown]
# ``` This is a normal paragraph: This is a code block. end code block. ```

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 5. 수평선 <font>
# > 아래 줄은 모두 수평선을 만든다. 마크다운 문서를 미리보기로 출력할 때 페이지 나누기 용도로 많이 사용한다.

# %% [markdown]
# <hr>
# * * *
#
# ***
#
# *****
#
# - - -
#
# ---------------------------------------

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 6. 링크 <font>

# %% [markdown]
# ● 참조링크

# %% [raw]
# [link keyword][id]
# [id]: URL "Optional Title here"

# %% [markdown]
# [link keyword][id]
# [id]: URL "Optional Title here"

# %% [raw]
# Link: [Google][googlelink]
# [googlelink]: https://google.com "Go google"

# %% [markdown]
# Link: [Google][googlelink]
# [googlelink]: https://google.com "Go google"

# %% [markdown]
# ● 인라인 링크

# %% [raw]
# > syntax: [Title](link)
#
# [googlelink]: [https://google.com "Go google"]

# %% [markdown]
# [googlelink]: [https://google.com "Go google"]

# %% [markdown]
# ● 자동 연결

# %% [raw]
# <http://example.com/>
# <address@example.com>

# %% [markdown]
# <http://example.com/>
# <address@example.com>

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 7. 강조 <font>

# %% [raw]
# *single asterisks*
# _single underscores_
# **double asterisks**
# __double underscores__
# ++underline++
# ~~cancelline~~

# %% [markdown]
# *single asterisks*
# _single underscores_
# **double asterisks**
# __double underscores__
# ++underline++
# ~~cancelline~~

# %% [markdown]
# <hr>
#
# ### <font color="brown"> 8. 이미지 <font>

# %% [raw]
# <hr>
# ### <font color="brown"> 6. 링크 <font>![Alt text](../images/BPC_Logo_text_v1612_2.png)
# ![Alt text](../images/jupyter.jpg "Optional title")

# %% [markdown]
# ![Alt text](../images/BPC_Logo_text_v1612_2.png)
# ![Alt text](../images/jupyter.jpg "Optional title")
