# %% [markdown]
# # Industry 4.0 의 중심, BigData

# %% [markdown]
# <div align='right'><font size=2 color='gray'>Data Processing Based Python @ <font color='blue'><a href='https://www.facebook.com/jskim.kr'>FB / jskim.kr</a></font>, [김진수](bigpycraft@gmail.com)</font></div>
# <hr>

# %% [markdown]
# ## <font color='brown'>랭킹정보 가져오기 </font>

# %% [markdown]
# ## NAVER 영화 랭킹
# > URL ::  https://movie.naver.com/movie/sdb/rank/rmovie.naver
# > - 영화랭킹 TOP10 정보 크롤링
# > - 데이터수집 : 순위, 영화명, 변동폭, 평점(관람객/평론가/네티즌), 장르, 감독, 출연, 등급

# %%
from package import mvr_step1_crawler as crawler1
from package import mvr_step2_crawler as crawler2

import pandas as pd

# %% [markdown]
# ### <font color='blue'>1단계 : 리스트 크롤링 </font>
# > **데이터수집 : 순위, 영화명, 변동폭**, ~평점(관람객/평론가/네티즌), 장르, 감독, 출연, 등급~

# %%
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
top10_df = crawler1.crawl_movie_list_top10(url)

# %%
top10_df
# Out:
#                                영화명 변동폭  \
# 순위
# 1                            범죄도시2   0
# 2                     쥬라기 월드: 도미니언   0
# 3                              브로커   0
# 4              닥터 스트레인지: 대혼돈의 멀티버스   0
# 5                   니 부모 얼굴이 보고 싶다   1
# 6                           그대가 조국  -1
# 7      마녀(魔女) Part2. The Other One   0
# 8                            카시오페아   0
# 9                          탑건: 매버릭   0
# 10  극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미   0
#
#                                                    링크
# 순위
# 1   https://movie.naver.com/movie/bi/mi/basic.nave...
# 2   https://movie.naver.com/movie/bi/mi/basic.nave...
# 3   https://movie.naver.com/movie/bi/mi/basic.nave...
# 4   https://movie.naver.com/movie/bi/mi/basic.nave...
# 5   https://movie.naver.com/movie/bi/mi/basic.nave...
# 6   https://movie.naver.com/movie/bi/mi/basic.nave...
# 7   https://movie.naver.com/movie/bi/mi/basic.nave...
# 8   https://movie.naver.com/movie/bi/mi/basic.nave...
# 9   https://movie.naver.com/movie/bi/mi/basic.nave...
# 10  https://movie.naver.com/movie/bi/mi/basic.nave...

# %%
file_name_step1 = 'data/movie_top10.csv'
top10_df.to_csv(file_name_step1, encoding='UTF-8')

# %% [markdown]
# ### <font color='blue'>2단계 : 상세페이지 크롤링 </font>
# > **항목** : ~순위, 영화명, 변동폭,~ **평점(관람객/평론가/네티즌), 장르, 감독, 출연, 등급**

# %%
df = pd.read_csv(file_name_step1, encoding='UTF-8', index_col='순위')
df
# Out:
#                                영화명  변동폭  \
# 순위
# 1                            범죄도시2    0
# 2                     쥬라기 월드: 도미니언    0
# 3                              브로커    0
# 4              닥터 스트레인지: 대혼돈의 멀티버스    0
# 5                   니 부모 얼굴이 보고 싶다    1
# 6                           그대가 조국   -1
# 7      마녀(魔女) Part2. The Other One    0
# 8                            카시오페아    0
# 9                          탑건: 매버릭    0
# 10  극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미    0
#
#                                                    링크
# 순위
# 1   https://movie.naver.com/movie/bi/mi/basic.nave...
# 2   https://movie.naver.com/movie/bi/mi/basic.nave...
# 3   https://movie.naver.com/movie/bi/mi/basic.nave...
# 4   https://movie.naver.com/movie/bi/mi/basic.nave...
# 5   https://movie.naver.com/movie/bi/mi/basic.nave...
# 6   https://movie.naver.com/movie/bi/mi/basic.nave...
# 7   https://movie.naver.com/movie/bi/mi/basic.nave...
# 8   https://movie.naver.com/movie/bi/mi/basic.nave...
# 9   https://movie.naver.com/movie/bi/mi/basic.nave...
# 10  https://movie.naver.com/movie/bi/mi/basic.nave...

# %%
final_df = crawler2.crawl_movie_detail_page(df)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
final_df
# Out:
#                                영화명  변동폭                              평점  \
# 순위
# 1                            범죄도시2    0  관람객:9.07 / 평론가:6.56 / 네티즌:9.51
# 2                     쥬라기 월드: 도미니언    0  관람객:6.85 / 평론가:6.40 / 네티즌:6.18
# 3                              브로커    0  관람객:7.47 / 평론가:6.80 / 네티즌:6.22
# 4              닥터 스트레인지: 대혼돈의 멀티버스    0  관람객:7.79 / 평론가:6.80 / 네티즌:7.33
# 5                   니 부모 얼굴이 보고 싶다    1  관람객:7.75 / 평론가:6.14 / 네티즌:7.68
# 6                           그대가 조국   -1  관람객:9.82 / 평론가:5.00 / 네티즌:7.22
# 7      마녀(魔女) Part2. The Other One    0  관람객:0.00 / 평론가:0.00 / 네티즌:0.00
# 8                            카시오페아    0  관람객:8.38 / 평론가:6.50 / 네티즌:9.22
# 9                          탑건: 매버릭    0  관람객:0.00 / 평론가:0.00 / 네티즌:0.00
# 10  극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미    0  관람객:7.97 / 평론가:6.00 / 네티즌:7.13
#
#              장르         감독                                               출연  \
# 순위
# 1        범죄, 액션        이상용                     마동석(마석도), 손석구(강해상), 최귀화(전일만)
# 2        액션, 모험   콜린 트레보로우            크리스 프랫(오웬 그래디), 브라이스 달라스 하워드(클레어 디어링)
# 3           드라마  고레에다 히로카즈                                    송강호, 강동원, 배두나
# 4   액션, 판타지, 모험      샘 레이미  베네딕트 컴버배치(닥터 스트레인지), 엘리자베스 올슨(완다 막시모프 / 스칼렛 위치)
# 5           드라마        김지훈                                              설경구
# 6         다큐멘터리        이승준                                             None
# 7            액션        박훈정                                    신시아, 박은빈, 서은수
# 8           드라마        신연식                        안성기(인우), 서현진(수진), 주예림(지나)
# 9            액션    조셉 코신스키             톰 크루즈(매버릭), 마일즈 텔러(루스터), 제니퍼 코넬리(페니)
# 10        애니메이션   유야마 쿠니히코                       이선호, 김영선, 마츠모토 리카(사토시 목소리)
#
#               등급                    흥행  \
# 순위
# 1   [국내] 15세 관람가  9,575,030명(06.08 기준)
# 2   [국내] 12세 관람가  2,266,199명(06.08 기준)
# 3   [국내] 12세 관람가    152,364명(06.08 기준)
# 4   [국내] 12세 관람가  5,861,671명(06.08 기준)
# 5   [국내] 15세 관람가                  None
# 6   [국내] 12세 관람가    300,516명(06.08 기준)
# 7   [국내] 15세 관람가                  None
# 8   [국내] 12세 관람가     17,954명(06.08 기준)
# 9   [국내] 12세 관람가                  None
# 10   [국내] 전체 관람가    397,784명(06.08 기준)
#
#                                                    링크
# 순위
# 1   https://movie.naver.com/movie/bi/mi/basic.nave...
# 2   https://movie.naver.com/movie/bi/mi/basic.nave...
# 3   https://movie.naver.com/movie/bi/mi/basic.nave...
# 4   https://movie.naver.com/movie/bi/mi/basic.nave...
# 5   https://movie.naver.com/movie/bi/mi/basic.nave...
# 6   https://movie.naver.com/movie/bi/mi/basic.nave...
# 7   https://movie.naver.com/movie/bi/mi/basic.nave...
# 8   https://movie.naver.com/movie/bi/mi/basic.nave...
# 9   https://movie.naver.com/movie/bi/mi/basic.nave...
# 10  https://movie.naver.com/movie/bi/mi/basic.nave...

# %%
file_name_step2 = 'data/movie_top10_final.csv'
final_df.to_csv(file_name_step2, encoding='UTF-8')

# %%
# %ls data\movie*
# Out:
#  F 드라이브의 볼륨: Samsung_T5
#  볼륨 일련 번호: 844F-BA7F
#
#  F:\project\itech_lab\_jbfg-ds22\ds22-ipynb\s60-web-crawling\data 디렉터리
#
# 2022-06-10  오전 01:44               987 movie_top10.csv
# 2022-06-10  오전 01:44             2,823 movie_top10_final.csv
#                2개 파일               3,810 바이트
#                0개 디렉터리  139,978,997,760 바이트 남음

# %% [markdown]
# <hr>
# <marquee><font size=3 color='brown'>The BigpyCraft find the information to design valuable society with Technology & Craft.</font></marquee>
# <div align='right'><font size=2 color='gray'> &lt; The End &gt; </font></div>
